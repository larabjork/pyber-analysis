# %%
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total far in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with the MATLAB method
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt(), which is the object-oriented interface method
fig, ax = plt.subplots() #this creates a figure (fig references the figure)
ax.plot(x_axis, y_axis) #this defines the axes(ax referneces the figure and allows annotations)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
# with only the two lines above, you get an empty chart
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Using plt.show(), which looks for all active figure objects and opens a window that displays them if there are 2+ sets of data to plot
# Create the plot
plt.plot(x_axis, y_axis)
plt.show()

# %%
#5.1.4 - Annotating MATLAB charts
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label = "Boston")
# Create labels for x, y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("PyBer Fare by Month")
# Add the legend
plt.legend()

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label = "Boston")
# Create labels for x, y axes
plt.xlabel("Date")
plt.ylabel("Fare ($)")
# Set the y limit between 0 and 45
plt.ylim(0, 45)
# Create a title
plt.title("PyBer Fare by Month")
# Add a grid
plt.grid()
# Add the legend
plt.legend()

# %%
#Annotating O-O Interface Charts

# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
# with only the two lines above, you get an empty chart
ax.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label = "Boston")
# Create labels for x, y axes
ax.set_xlabel("Date")
ax.set_ylabel("Fare ($)")
# Set the y limit between 0 and 45
ax.set_ylim(0, 45)
# Create a title
ax.set_title("PyBer Fare by Month")
# Add a grid
ax.grid()
# Add the legend
ax.legend()

# %%
# 5.1.5. Create bar charts with MATLAB approach
# Vertical bar chart

# Create the plot with .bar function
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with .bar function
plt.bar(x_axis, y_axis, color = "green", label = "Boston")
# Create labels for x, y axes
plt.xlabel("Date")
plt.ylabel("Fares $")
# Create a title
plt.title("PyBer Fare by Month")
# Add a legend
plt.legend()

# %%
# Horizontal bar chart with .barh function
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Swap axes (i.e., so dates read left right not up/down)
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Invert order of dates, so January at top, Dec at bottom
# Create the plot
plt.barh(x_axis, y_axis)
# use gca method to "get current axis" then "invert_yaxis"
plt.gca().invert_yaxis()

# %%
# Annotate the axes
# Create the plot
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
# use gca method to "get current axis" then "invert_yaxis"
plt.gca().invert_yaxis()
# add title and axes labels
plt.title("PyBer Fare by Month")
plt.ylabel("Date")
plt.xlabel("Fares ($)")
# add a legend
plt.legend()

# %%
# 5.1.6 Bar charts with O-O Approach
# Vertical bar chart
# Create plot with ax.subplots()
fix, ax = plt.subplots()
# Use .bar() to create bar chart
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Horizontal bar chart
# Create the plot with .subplots()
fig, ax = plt.subplots()
# Create horizontal bar chart with barh()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Swap x, y positions, even though it's not helpful for this data
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Skill drill
# Change bar color to cyan
# Switch so that Fares is on x axis
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
# Add legend for city of Chicago
ax.legend()
# Add title and axes labels
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fares ($)")
ax.set_ylabel("Date")
# Invert y-axis data
ax.invert_yaxis()

# %%
# 5.1.7 Scatter Plots
# Using MATLAB approach and plt.plot()
plt.plot(x_axis, y_axis, 'o')

# %%
# Using plt.scatter()
plt.scatter(x_axis, y_axis)

# %%
# Skill Drill - MATLAB approach
# Change marker color to red
# Swtich position of axes
plt.plot(y_axis, x_axis, "o", color = "red", label = "Chicago")
# Add title and axes labels
plt.title("PyBer Fares by Month")
plt.ylabel("Date")
plt.xlabel("Fares ($)")
# Add a limit for x-axis data
plt.xlim(0,45)
# Add legend for city as Chicago
plt.legend()
# Invert y-axis so January in top
plt.gca().invert_yaxis()

# %%
# Create a bubble chart using MATLAB method
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Make markers larger
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
    
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Simplify code for making markers larger
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Scatter plot with obj-oriented interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Bubble chart with obj-oriented interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s = y_axis)

# %%
# Skill Drill with obj oriented
# Change marker color to sky blue
# Change size of markers to 5x the data point
# Make color 20% transparent
# Make the line width of the circles = 2 pts
# Add black edge color to circles
# Switch so fares are on x axis
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color = "xkcd:sky blue", s = [i * 5 for i in y_axis], alpha = .2, edgecolors = "k", linewidths = 2, label = "Boston")
# Add a legend for the city of Boston
ax.legend()
# Add a title
ax.set_title("PyBer Fares by Month")
ax.set_xlabel("Fares ($)")
ax.set_ylabel("Date")
# Add a limit for x-axis data
ax.set_xlim(0,45)
# Invert the y-axis so January is on top
ax.invert_yaxis()

# %%
# 5.1.8 Pie charts
# MATLAB approach
plt.pie(y_axis, labels = x_axis)
plt.show()

# %%
# Adding percentages, custom colors, and popping out wedges
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode = explode_values, labels = x_axis, autopct = "%.1f%%")
plt.show()

# %%
# Increasing overall pie chart size to make it more legible
plt.subplots(figsize= (8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode = explode_values, labels = x_axis, autopct = "%.1f%%")
plt.show()

# %%
# Changing colors from default
# Assign 12 colors (1 per month)
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize= (8, 8))
plt.pie(y_axis, 
        explode = explode_values, 
        colors = colors,
        labels = x_axis, 
        autopct = "%.1f%%")
plt.show()

# %%
# Pie chart with obj-oriented interface
fig, ax = plt.subplots()
ax.pie(y_axis, labels = x_axis)
plt.show()

# %%
# Skill Drill
exploding = [0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0]

fig, ax = plt.subplots(figsize = (8,8))
ax.pie(y_axis,
       colors = colors,
       explode = exploding,
       shadow = True,
       startangle = 90,
       labels = x_axis,
       autopct = "%.1f%%", 
          )
plt.show
       
# Add a percentage to 1 decimal place to each wedge
# Increase figure size to 8x8
# Explode the two months with highest percentages
# Add a shadow
# Add a start angle so January is on top
# Reverse the order so that the months are clockwise
# Add new color palette or the previous one
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
